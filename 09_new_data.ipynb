# %%
import pandas as pd
import numpy as np

df = pd.read_csv("panel_ML_df.csv")
df = df.drop(columns=['ORDEM','IDENT','CLASSE','CODIGO', 'CNPJ', 'ID_ECONO', 'NAICS_II', 'trimestre'])
df['DATA'] = pd.to_datetime(df['DATA'], format='%d%b%Y')


df['ANO'] = df['DATA'].dt.year
df['TRIMESTRE'] = df['DATA'].dt.quarter

df = df[~((df['ANO'] == 2009) & (df['TRIMESTRE'].isin([3, 4])))]
df.drop(columns=['ANO', 'TRIMESTRE'], inplace=True)
df = df.sort_values(by=['NOME', 'DATA']).reset_index(drop=True)
df = df[~df['NAICS_I'].str.contains('Servi.os financeiros e seguros', case=False, na=False, regex=True)]
df = df.drop(columns=['NAICS_I'])
df
# Out:
#             DATA     NOME  AT  AT_CIR  CAIXA_EQ  ANC  RLP  IMOB  INVEST  \
# 0     2010-03-31  3tentos NaN     NaN       NaN  NaN  NaN   NaN     NaN
# 1     2010-06-30  3tentos NaN     NaN       NaN  NaN  NaN   NaN     NaN
# 2     2010-09-30  3tentos NaN     NaN       NaN  NaN  NaN   NaN     NaN
# 3     2010-12-31  3tentos NaN     NaN       NaN  NaN  NaN   NaN     NaN
# 4     2011-03-31  3tentos NaN     NaN       NaN  NaN  NaN   NaN     NaN
# ...          ...      ...  ..     ...       ...  ...  ...   ...     ...
# 51955 2023-12-31     Zivi NaN     NaN       NaN  NaN  NaN   NaN     NaN
# 51956 2024-03-31     Zivi NaN     NaN       NaN  NaN  NaN   NaN     NaN
# 51957 2024-06-30     Zivi NaN     NaN       NaN  NaN  NaN   NaN     NaN
# 51958 2024-09-30     Zivi NaN     NaN       NaN  NaN  NaN   NaN     NaN
# 51959 2024-12-31     Zivi NaN     NaN       NaN  NaN  NaN   NaN     NaN
#
#        PA_CIR  ...  g_FCFF  g_FCFE  ROE  CI  ROIC  b_PL  b_NOPAT  LC  GIRO_AT  \
# ...

# %%
df = df.dropna(subset=['FCFF', 'FCFE', 'g_FCFF', 'g_FCFE', 'lnAT', 'ROIC', 'b_NOPAT', 'GIRO_AT', 'LEV', 'LC', 'ROE', 'b_PL'])
df = df[df['PL'] > 0]
df
# Out:
#             DATA       NOME         AT     AT_CIR  CAIXA_EQ        ANC  \
# 45    2021-06-30    3tentos  3731347.0  3079581.0  161896.0   651766.0
# 46    2021-09-30    3tentos  4353136.0  3555877.0  560333.0   797259.0
# 47    2021-12-31    3tentos  4395601.0  3354305.0  351590.0  1041296.0
# 48    2022-03-31    3tentos  5016524.0  3833602.0  720271.0  1182922.0
# 51    2022-12-31    3tentos  6081989.0  4257219.0  724314.0  1824770.0
# ...          ...        ...        ...        ...       ...        ...
# 51895 2023-12-31  Zamp S.A.  4117466.0   902077.0   81279.0  3215389.0
# 51896 2024-03-31  Zamp S.A.  4590902.0  1430381.0   73419.0  3160521.0
# 51897 2024-06-30  Zamp S.A.  4331322.0  1194092.0   31843.0  3137230.0
# 51898 2024-09-30  Zamp S.A.  4654390.0  1456330.0   21208.0  3198060.0
# 51899 2024-12-31  Zamp S.A.  4677970.0  1303166.0   48259.0  3374804.0
#
#             RLP       IMOB  INVEST     PA_CIR  ...      g_FCFF     g_FCFE  \
# ...

# %%
df.to_csv('clean_panel.csv')
